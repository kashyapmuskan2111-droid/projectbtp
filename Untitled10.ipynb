# %% [markdown]
# <a href="https://colab.research.google.com/github/kashyapmuskan2111-droid/projectbtp/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import zipfile

#extraction of zip file
with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('emotion_data')

#load dataframe
df = pd.read_csv('emotion_data/train.txt', sep=';', names=['Text', 'Emotion'])

print("Step 1 Complete: 16,000 sentences successfully loaded")
print(df.head())
# Out:
# Step 1 Complete: 16,000 sentences successfully loaded
#                                                 Text  Emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
#preprocessing
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
  #remove noise and lowercase
    text = re.sub('[^a-zA-Z]', ' ', text).lower()
    words = text.split()
    # Stemming:
    return " ".join([ps.stem(w) for w in words if w not in stop_words])

df['Clean_Text'] = df['Text'].apply(clean_text)
print("Step 2 Complete: cleaning is done") #data normalization
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Step 2 Complete: cleaning is done

# %%
#Feature Extraction (TF-IDF)
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

tfidf = TfidfVectorizer(max_features=2000)
X = tfidf.fit_transform(df['Clean_Text']).toarray()

# BiLSTM takes 3D input: (Samples, Time-steps, Features)
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# convert emotions into nos.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(df['Emotion'])

print("Step 3 Complete: Text successfully converted into nos. (Tensors) !")
# Out:
# Step 3 Complete: Text successfully converted into nos. (Tensors) !

# %%
#BiLSTM Hybrid Model Training
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout

model = Sequential([
    Bidirectional(LSTM(64, activation='tanh'), input_shape=(1, 2000)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(len(le.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

print("Step 4: BiLSTM Training starts(Epochs: 10)...")
history = model.fit(X, y, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Step 4: BiLSTM Training starts(Epochs: 10)...
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.5472 - loss: 1.2408 - val_accuracy: 0.8150 - val_loss: 0.6129
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8569 - loss: 0.4293 - val_accuracy: 0.8528 - val_loss: 0.4317
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9095 - loss: 0.2769 - val_accuracy: 0.8459 - val_loss: 0.4504
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9283 - loss: 0.2154 - val_accuracy: 0.8409 - val_loss: 0.4786
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 1. Accuracy Graph
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('BiLSTM Model Accuracy')
plt.legend()
plt.show()

# 2. Confusion Matrix (Asli vs Predicted)
y_pred = np.argmax(model.predict(X), axis=1)
cm = confusion_matrix(y, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Result')
plt.show()
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
import matplotlib.pyplot as plt

# 1. Accuracy Graph
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('BiLSTM Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 2. Loss Graph
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='red', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange', marker='o')
plt.title('BiLSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Predictions
y_pred = np.argmax(model.predict(X), axis=1)
cm = confusion_matrix(y, y_pred)

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_, cmap='Blues')
plt.title('Final Confusion Matrix - BiLSTM')
plt.xlabel('Predicted Emotion')
plt.ylabel('Actual Emotion')
plt.show()
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
